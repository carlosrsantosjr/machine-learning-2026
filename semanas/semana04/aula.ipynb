# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosrsantosjr/machine-learning-2026/blob/main/semanas/semana04/aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Árvore de Decisão

# %% [markdown]
# ---
#
#
# **Machine Learning**
#
# Tecnologia em Análise e Desenvolvimento de Sistemas
#
# Instituto Federal de Mato Grosso do Sul - Câmpus Três Lagoas
#
# Prof. Carlos R Santos Jr
#
# 1° Semestre de 2026
#
# ---

# %%
print("Teste")
# Out:
# Teste
